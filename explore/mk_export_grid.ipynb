# %%
from pathlib import Path
import geopandas as gpd

# %%
data = Path("../data/shapefiles/nts_snrc_250k_yk_selection.shp")
grid = gpd.read_file(data)
grid.head()
# Out:
#   NTS_SNRC       NAME_ENG        NOM_FRA  SRID  SHAPE_AREA  SHAPE_LEN  \
# 0     115C           None           None     6         2.0        6.0
# 1     115F           None           None     6         2.0        6.0
# 2     115G    KLUANE LAKE    KLUANE LAKE     6         2.0        6.0
# 3     105K      TAY RIVER      TAY RIVER     6         2.0        6.0
# 4     105L  GLENLYON LAKE  GLENLYON LAKE     6         2.0        6.0
#
#                                             geometry
# 0  POLYGON ((-140.00000 60.00000, -140.01667 60.0...
# 1  POLYGON ((-140.00000 61.00000, -140.01667 61.0...
# 2  POLYGON ((-139.98333 61.00000, -140.00000 61.0...
# 3  POLYGON ((-133.98333 62.00000, -134.00000 62.0...
# 4  POLYGON ((-135.98333 62.00000, -136.00000 62.0...

# %%
grid['ft'] = 0
grid['ta'] = 0

# %%
grid
# Out:
#    NTS_SNRC            NAME_ENG             NOM_FRA  SRID  SHAPE_AREA  \
# 0      115C                None                None     6         2.0
# 1      115F                None                None     6         2.0
# 2      115G         KLUANE LAKE         KLUANE LAKE     6         2.0
# 3      105K           TAY RIVER           TAY RIVER     6         2.0
# 4      105L       GLENLYON LAKE       GLENLYON LAKE     6         2.0
# ..      ...                 ...                 ...   ...         ...
# 58     116P          BELL RIVER          BELL RIVER     6         2.0
# 59     117A          BLOW RIVER          BLOW RIVER     6         4.0
# 60     117B  DAVIDSON MOUNTAINS  DAVIDSON MOUNTAINS     6         2.0
# 61     117C     BACKHOUSE RIVER     BACKHOUSE RIVER     6         2.0
# 62     117D     HERSCHEL ISLAND     HERSCHEL ISLAND     6         4.0
#
#     SHAPE_LEN                                           geometry  ft  ta
# ...

# %%
grid.to_file("../data/shapefiles/grid.shp")
